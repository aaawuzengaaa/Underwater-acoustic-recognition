# %% [markdown]
# # 水下声学信号数据探索
#
# 本笔记本用于探索和可视化水下声学信号数据集。

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
from pathlib import Path

# %% [markdown]
# ## 1. 加载音频文件

# %%
# 加载示例音频
# audio_path = 'data/raw/normal/example.wav'
# audio, sr = librosa.load(audio_path, sr=44100)
# print(f'采样率: {sr}')
# print(f'音频长度: {len(audio)/sr:.2f} 秒')

# %% [markdown]
# ## 2. 可视化波形

# %%
# plt.figure(figsize=(12, 4))
# librosa.display.waveshow(audio, sr=sr)
# plt.title('Waveform')
# plt.xlabel('Time (s)')
# plt.ylabel('Amplitude')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 3. 频谱图分析

# %%
# # 计算频谱图
# spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)
# spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)
# 
# plt.figure(figsize=(12, 4))
# librosa.display.specshow(spectrogram_db, sr=sr, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title('Mel Spectrogram')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 4. MFCC特征

# %%
# # 提取MFCC
# mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
# 
# plt.figure(figsize=(12, 4))
# librosa.display.specshow(mfcc, sr=sr, x_axis='time')
# plt.colorbar()
# plt.title('MFCC')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. 数据集统计

# %%
# # 统计各类别样本数量
# data_dir = 'data/raw'
# classes = os.listdir(data_dir)
# sample_counts = {}
# 
# for cls in classes:
#     cls_dir = os.path.join(data_dir, cls)
#     if os.path.isdir(cls_dir):
#         count = len([f for f in os.listdir(cls_dir) if f.endswith(('.wav', '.flac', '.mp3'))])
#         sample_counts[cls] = count
# 
# # 绘制柱状图
# plt.figure(figsize=(10, 5))
# plt.bar(sample_counts.keys(), sample_counts.values())
# plt.xlabel('Class')
# plt.ylabel('Number of Samples')
# plt.title('Sample Distribution')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
